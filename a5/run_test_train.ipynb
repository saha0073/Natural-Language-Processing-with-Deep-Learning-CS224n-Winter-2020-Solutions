# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment3/'
FOLDERNAME = 'AI/ManningNLP/a5'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# this downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
#%cd /content/drive/My\ Drive/$FOLDERNAME/
#!bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME/
# %cd /content
# %cd /content/drive/My\ Drive/$FOLDERNAME/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/AI/ManningNLP/a5
# /content
# /content/drive/My Drive/AI/ManningNLP/a5

# %%
# !pip install -r gpu_requirements.txt
# Out:
# ...
#      |████████████████████████████████| 51kB 1.6MB/s
# ...
# ERROR: spacy 2.2.4 has requirement tqdm<5.0.0,>=4.38.0, but you'll have tqdm 4.29.1 which is incompatible.
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# ...

# %%
# !sh run.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 164.23, avg. ppl 19646.07 cum. examples 320, speed 3047.95 words/sec, time elapsed 1.74 sec
# epoch 1, iter 20, avg. loss 140.72, avg. ppl 2900.51 cum. examples 640, speed 4407.15 words/sec, time elapsed 3.03 sec
# epoch 1, iter 30, avg. loss 138.40, avg. ppl 1826.89 cum. examples 960, speed 4268.50 words/sec, time elapsed 4.41 sec
# epoch 1, iter 40, avg. loss 131.84, avg. ppl 1777.22 cum. examples 1280, speed 3978.92 words/sec, time elapsed 5.82 sec
# epoch 1, iter 50, avg. loss 132.88, avg. ppl 1597.13 cum. examples 1600, speed 4568.91 words/sec, time elapsed 7.09 sec
# epoch 1, iter 60, avg. loss 128.56, avg. ppl 1479.47 cum. examples 1920, speed 4361.69 words/sec, time elapsed 8.38 sec
# epoch 1, iter 70, avg. loss 118.48, avg. ppl 1363.29 cum. examples 2240, speed 4001.40 words/sec, time elapsed 9.69 sec
# ...

# %%
# !sh run.sh train_local_q2
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 2, iter 10, avg. loss 54.21, avg. ppl 15.04 cum. examples 20, speed 127.01 words/sec, time elapsed 3.15 sec
# epoch 4, iter 20, avg. loss 48.79, avg. ppl 11.47 cum. examples 40, speed 137.58 words/sec, time elapsed 6.06 sec
# epoch 6, iter 30, avg. loss 46.99, avg. ppl 10.48 cum. examples 60, speed 133.07 words/sec, time elapsed 9.06 sec
# epoch 8, iter 40, avg. loss 45.93, avg. ppl 9.94 cum. examples 80, speed 147.99 words/sec, time elapsed 11.77 sec
# epoch 10, iter 50, avg. loss 44.86, avg. ppl 9.42 cum. examples 100, speed 147.59 words/sec, time elapsed 14.48 sec
# epoch 12, iter 60, avg. loss 43.98, avg. ppl 9.02 cum. examples 120, speed 133.29 words/sec, time elapsed 17.48 sec
# epoch 14, iter 70, avg. loss 42.66, avg. ppl 8.44 cum. examples 140, speed 131.52 words/sec, time elapsed 20.52 sec
# ...

# %% [markdown]
# **Achieved a BLEU score of 99 when trained & tested on the small dataset, so the code should be correct and it also should achieve decent BLEU score when trained and tested in the GPU with large dataset**

# %%
# !sh run.sh test_local_q2
# Out:
# load test source sentences from [./en_es_data/test_tiny.es]
# load test target sentences from [./en_es_data/test_tiny.en]
# load model from model.bin
# Decoding:   0% 0/4 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# Decoding: 100% 4/4 [00:00<00:00,  4.98it/s]
# Corpus BLEU: 99.29792465574434

# %%
# %ls -la
# Out:
# total 40326
# -rw------- 1 root root   681637 Dec 27  2019 a5.pdf
# -rw------- 1 root root     7780 Jul 19 21:32 char_decoder.py
# -rw------- 1 root root     1472 Jul 19 17:32 cnn.py
# -rw------- 1 root root       99 Feb 15  2019 collect_submission.sh
# drwx------ 2 root root     4096 Jul 19 21:33 en_es_data/
# -rw------- 1 root root       25 Feb 12  2019 gpu_requirements.txt
# -rw------- 1 root root     1410 Jul 19 15:21 highway.py
# -rw------- 1 root root        0 Feb 12  2019 __init__.py
# -rw------- 1 root root      175 Feb 15  2019 local_env.yml
# -rw------- 1 root root 12752739 Jul 19 20:50 model.bin
# -rw------- 1 root root 25492558 Jul 19 20:50 model.bin.optim
# -rw------- 1 root root     3348 Jul 19 17:32 model_embeddings.py
# -rw------- 1 root root    20737 Jul 19 20:14 nmt_model.py
# drwx------ 2 root root     4096 Jul 19 21:33 outputs/
# drwx------ 2 root root     4096 Jul 19 21:33 __pycache__/
# -rw------- 1 root root    15419 Jul 19 21:33 run.py
# ...
